# %% [markdown]
# ## Import

# %% [markdown]
# Example of journalling along with the codebase.

# %%
import os
import numpy as np
import pandas as pd
import pint
from lolviz import *
# %matplotlib inline
import matplotlib as plt
plt.style.use('seaborn')

# %%
from pint import UnitRegistry
# First we create the registry.
ureg = UnitRegistry()
#time = UnitRegistry()

# Then we append the new definitions
ureg.load_definitions('/Users/rv939730/Learn/DeepLearningHardware/DL_Papers_Summaries/myunits.txt')

# %%
listviz(['hi','mom',{3,4},{"parrt":"user"}])

# %%
Q_ = ureg.Quantity

define_in_bites = Q_(10, 'byte')

print(define_in_bites.to('bit'))
# Out:
# 80.0 bit

# %% [markdown]
# Q_ = ureg.Quantity
#
# lassie_lifespan = Q_(10, 'bytes')
#
# print(lassie_lifespan.to('bytes'))
#
# def mypp_caveman(length):
#
#     return pendulum_period(length.to(ureg.meter).magnitude) * ureg.second
# https://pint.readthedocs.io/en/latest/wrapping.html

# %% [markdown]
# # Small

# %% [markdown]
# ## Basys-3 Board

# %% [markdown]
# https://store.digilentinc.com/basys-3-artix-7-fpga-trainer-board-recommended-for-introductory-users/

# %%
basys_3 = {}
basys_3["name"] = "basys_3"
basys_3["performance"] = "NA"
basys_3["power_eff"] = 'NA'
basys_3["resolution"] = 'NA'
basys_3["frequency"] = "NA"
basys_3["memory"] = Q_(128,'kbytes')
basys_3["mac_count"] =  'NA'
basys_3["transistor_count"] = 'NA'
basys_3["core_count"] = 'NA'
basys_3["technology"] = 'NA'
basys_3["manufacturer"] = 'NA'

#dictviz(basys_3)
basys_3
# Out:
# {'core_count': 'NA',
#  'frequency': 'NA',
#  'mac_count': 'NA',
#  'memory': <Quantity(128, 'kilobyte')>,
#  'name': 'basys_3',
#  'performance': 'NA',
#  'power_eff': 'NA',
#  'resolution': 'NA',
#  'technology': 'NA',
#  'transistor_count': 'NA'}

# %%
cmod_s6 = {}
cmod_s6["name"] = "cmod_s6"
cmod_s6["performance"] = "NA"
cmod_s6["power_eff"] = 'NA'
cmod_s6["resolution"] = 'NA'
cmod_s6["frequency"] = "NA"
cmod_s6["memory"] = Q_(128,'kbytes')
cmod_s6["mac_count"] =  'NA'
cmod_s6["transistor_count"] = 'NA'
cmod_s6["core_count"] = 'NA'
cmod_s6["technology"] = 'NA'
cmod_s6["manufacturer"] = 'Diligent'

# %% [markdown]
# # Summary

# %%
small_fpga = pd.DataFrame([basys_3])

#small_fpga = small_fpga.append([brainwave])

small_fpga = small_fpga.set_index('name')
small_fpga
# Out:
#         core_count frequency mac_count        memory performance power_eff  \
# name
# basys_3         NA        NA        NA  128 kilobyte          NA        NA
#
#         resolution technology transistor_count
# name
# basys_3         NA         NA               NA
